# %%
# !pip install langchain langchain_community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 97.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 75.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 7.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# ...

# %% [markdown]
# set up environment

# %%
import os

# %%
os.environ['OPENAI_API_KEY']=""
os.environ["HUGGINGFACEHUB_API_TOKEN"]=""

# %% [markdown]
# LLMs

# %% [markdown]
# openai

# %%
# !pip install openai

# %%
# !pip install langchain-openai
from langchain_openai import OpenAI
llm=OpenAI(temperature=0.9)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 501.4/501.4 kB 47.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.2.12
#     Uninstalling langchain-core-1.2.12:
#       Successfully uninstalled langchain-core-1.2.12
# ...

# %%
text="what would be a good company name for a company that makes colorful socks?"
print(llm.invoke(text))
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# /tmp/ipython-input-4111375961.py in <cell line: 0>()
#       1 text="what would be a good company name for a company that makes colorful socks?"
# ----> 2 print(llm.invoke(text))
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/llms.py in invoke(self, input, config, stop, **kwargs)
#     378         config = ensure_config(config)
#     379         return (
# --> 380             self.generate_prompt(
#     381                 [self._convert_input(input)],
#     382                 stop=stop,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/llms.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     789     ) -> LLMResult:
#     790         prompt_strings = [p.to_string() for p in prompts]
# ...

# %% [markdown]
# example 2

# %%
from langchain.llms import openai
llm=openai(temeperature = 0.5)
name=llm.invoke("I want to open a  restaurant for chinese food . suggest a fency name for this")
print(name)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-3427600942.py in <cell line: 0>()
# ----> 1 from langchain.llms import openai
#       2 llm=openai(temeperature = 0.5)
#       3 name=llm.invoke("I want to open a  restaurant for chinese food . suggest a fency name for this")
#       4 print(name)
#
# ModuleNotFoundError: No module named 'langchain.llms'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
reponse=llm("I want to open a  restaurant for chinese food . suggest a fency name for this")
print(response)

# %% [markdown]
# huggingface [ free alternative]

# %%
# !pip install huggingface_hub

# %%
from langchain_huggingface import HuggingFaceEndpoint

# %%
# !pip install -U langchain-huggingface
# Out:
# ...
#   Using cached huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# ...
# Using cached huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.4.1
#     Uninstalling huggingface_hub-1.4.1:
#       Successfully uninstalled huggingface_hub-1.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformers 5.0.0 requires huggingface-hub<2.0,>=1.3.0, but you have huggingface-hub 0.36.2 which is incompatible.
# datasets 4.0.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2026.2.0 which is incompatible.
# ...

# %%
from langchain_huggingface import HuggingFaceEndpoint

llm_mistral = HuggingFaceEndpoint(
    repo_id="mistralai/Mistral-7B-Instruct-v0.2",
    temperature=0.1,
    max_new_tokens=200,
    task="conversational"
)


print(llm_mistral.invoke("Translate English to German: How old are you?"))

# %% [markdown]
# example 2

# %%
# !pip install huggingface_hub

# %%
from langchain import huggingface_hub
llm=huggingface_hub(
    repo_id="google/flan-t5-large",
    temperature=0,
    max_new_tokens=64,
    task="text2text-generation"
)
name=llm.invoke("I want to open a restaurant for chinese food . suggest a fency name for this")
print(name)

# %%
name_openai = llm.invoke("I want to open a restaurant for chinese food. Suggest a fancy name for this.")
print(name_openai)

# %% [markdown]
# prompt templates
